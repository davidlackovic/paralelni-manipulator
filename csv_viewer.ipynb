# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
name = 'v3.0_TD3'
measurement_number = 0
#type = 'sim'
type = 'irl'
training_data_path = 'pybullet/training_data'
folder_path = os.path.join(training_data_path, name)
experiment_path = os.path.join(folder_path, 'experiments')
csv_file = os.path.join(experiment_path, f'{name}_{type}_experiment_{measurement_number}.csv')


df = pd.read_csv(csv_file)
csv_file
# Out:
# 'pybullet/training_data\\v2.3_TD3\\experiments\\v2.3_TD3_sim_experiment_0.csv'

# %%
df.head()
# Out:
#        time         x         y        vx        vy   theta_x   theta_y  \
# 0  0.079621  0.076706 -0.045594 -0.075713 -0.027830  0.063817 -0.002234
# 1  0.159054  0.071541 -0.048017 -0.079640 -0.038873 -0.011665 -0.021249
# 2  0.236950  0.066123 -0.050624 -0.082501 -0.038759 -0.005462  0.001513
# 3  0.314790  0.060555 -0.053250 -0.084538 -0.040566  0.013705 -0.008065
# 4  0.393604  0.054953 -0.055976 -0.082744 -0.040398 -0.011361  0.014790
#
#    action_x  action_y    radius
# 0  0.063818 -0.002234  0.089233
# 1 -0.075482 -0.019015  0.086161
# 2  0.006203  0.022763  0.083277
# 3  0.019167 -0.009578  0.080638
# 4 -0.025066  0.022855  0.078441

# %%
columns = ["time", "x", "y", "vx", "vy", "theta_x", "theta_y", "action_x", "action_y", "radius"]
variables = ["x", "y", "vx", "vy", "theta_x", "theta_y", "action_x", "action_y", "radius"]  # Variables to plot

time_min, time_max = 0, np.inf  # Time range for filtering
#time_min, time_max = 0, 30

mask = (df['time'] >= time_min) & (df['time'] <= time_max)

fig, axes = plt.subplots(5, 2, figsize=(12, 10))
df['time_ms'] = df['time'] * 1000

for ax, var in zip(axes.flat, variables):
    ax.plot(df.loc[mask, 'time'], df.loc[mask, var], 'b-')    
    ax.set_title(var, fontsize=12)
    ax.set_xlabel('Time (s)', fontsize=10)
    ax.set_ylabel(var, fontsize=10)
    ax.grid()
    ax.axhline(0, color='k', linestyle='--', linewidth=1)
    

plt.tight_layout()
plt.show()

# %%
name = 'v2.3_TD3'
measurement_number = 0
#type = 'sim'
type = 'irl'
training_data_path = 'pybullet/training_data'
folder_path = os.path.join(training_data_path, name)
experiment_path = os.path.join(folder_path, 'experiments')
csv_file = os.path.join(experiment_path, f'{name}_{type}_experiment_{measurement_number}.csv')


df = pd.read_csv(csv_file)
csv_file
# Out:
# 'pybullet/training_data\\v2.3_TD3\\experiments\\v2.3_TD3_irl_experiment_0.csv'

# %%
columns = ["time", "x", "y", "vx", "vy", "theta_x", "theta_y", "action_x", "action_y", "radius"]
variables = ["x", "y", "vx", "vy", "theta_x", "theta_y", "action_x", "action_y", "radius"]  # Variables to plot

time_min, time_max = 0, np.inf  # Time range for filtering
#time_min, time_max = 0, 30

mask = (df['time'] >= time_min) & (df['time'] <= time_max)

fig, axes = plt.subplots(5, 2, figsize=(12, 10))
df['time_ms'] = df['time'] * 1000

for ax, var in zip(axes.flat, variables):
    ax.plot(df.loc[mask, 'time'], df.loc[mask, var], 'b-')    
    ax.set_title(var, fontsize=12)
    ax.set_xlabel('Time (s)', fontsize=10)
    ax.set_ylabel(var, fontsize=10)
    ax.grid()
    ax.axhline(0, color='k', linestyle='--', linewidth=1)
    

plt.tight_layout()
plt.show()
