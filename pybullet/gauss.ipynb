# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def gauss(x, a, sigma):
    return a * np.exp(-x**2 / (2 * sigma**2))

# %%
X = np.linspace(-0.2, 0.2, 100)
X = np.linspace(-0.05, 0.05, 100)

# %%
plt.plot(X, gauss(X, 10, 0.01), color='red')
plt.title('Gauss')
#plt.axvline(x=-0.18, color='k', linestyle='--')
plt.axvline(x=0, color='k', linestyle='--')
#plt.axvline(x=0.18, color='k', linestyle='--')

# %% [markdown]
# ## Rotation matrix test

# %%
theta = np.deg2rad(30.75)
R = np.array([[np.cos(theta), -np.sin(theta)],
                        [np.sin(theta), np.cos(theta)]])

# %%
p_k = np.array([1, 3])
p_m = R @ p_k
p_mm = p_k @ R
p_m_manual = np.array([np.linalg.norm(p_k) * np.cos(theta),
                       np.linalg.norm(p_k) * np.sin(theta)])

p_k, p_m, p_mm
# Out:
# (array([1, 3]),
#  array([-0.67447285,  3.08951232]),
#  array([2.39328567, 2.06692615]))

# %%
alpha = np.radians(30)

# Define a point on each rotated axis (unit vectors)
x_dir = (np.cos(alpha), np.sin(alpha))         # Rotated X' direction
y_dir = (np.sin(-alpha), np.cos(-alpha))        # Rotated Y' direction

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')  
ax.quiver(0,0, p_k[0], p_k[1], angles='xy', scale_units='xy', scale=1, color='r')
ax.quiver(0,0, p_mm[0], p_mm[1], angles='xy', scale_units='xy', scale=1, color='b')
ax.axline((0, 0), slope=x_dir[1] / x_dir[0], color='k', linestyle='--', label="Rotated X'")
ax.axline((0, 0), slope=-x_dir[0] / x_dir[1], color='k', linestyle='--', label="Rotated Y'")
ax.axhline(0, color='k', linestyle='--', linewidth=1.5)
ax.axvline(0, color='k', linestyle='--', linewidth=1.5)
ax.set_aspect('equal')
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.grid()

# %%
-p_k
# Out:
# array([-1, -3])
