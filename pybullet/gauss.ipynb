# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def gauss(x, a, sigma):
    return a * np.exp(-x**2 / (2 * sigma**2))

# %%
X = np.linspace(-0.2, 0.2, 100)

# %%
plt.plot(X, gauss(X, 10, 0.045), color='red')
plt.title('Gauss')
plt.axvline(x=-0.18, color='k', linestyle='--')
plt.axvline(x=0, color='k', linestyle='--')
plt.axvline(x=0.18, color='k', linestyle='--')
